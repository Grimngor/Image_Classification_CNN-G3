# %% [markdown]
# # Convolutional Neural Networks Project
#
#
# ---

# %% [markdown]
# # Working with CIFAR-10
#
# The CIFAR-10 dataset consists of 60000 32x32 colour images in 10 classes, with 6000 images per class. There are 50000 training images and 10000 test images. More information about CIFAR-10 can be found [here](https://www.cs.toronto.edu/~kriz/cifar.html).
#
# In Keras, the CIFAR-10 dataset is also preloaded in the form of four Numpy arrays. x_train and y_train contain the training set, while x_test and y_test contain the test data. The images are encoded as Numpy arrays and their corresponding labels ranging from 0 to 9.
#
# ### Step 1:
#
# Visualize the images in CIFAR-10 dataset. Create a 10 x 10 plot showing 10 random samples from each class.

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical

# Load CIFAR-10 dataset
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# %%
# Create a 10x10 subplot grid
fig, axs = plt.subplots(10, 10, figsize=(6, 6))

# Iterate over each class
for i, c in enumerate(np.unique(y_train)):
    # Select 10 random samples from this class
    idx = np.random.choice(np.where(y_train == c)[0], 10, replace=False)
    
    # Iterate over the 10 random samples
    for j, idx_j in enumerate(idx):
        # Get the corresponding image
        img = x_train[idx_j]
        
        # Display the image in the subplot
        axs[j, i].imshow(img)
        axs[j, i].set_xticks([])
        axs[j, i].set_yticks([])

# Layout so plots do not overlap
fig.tight_layout()
plt.show()

# %% [markdown]
# ### Step 2:
#
# Convert the labels to one-hot encoding.

# %%
# Convert the labels to one-hot encoding
y_train = to_categorical(y_train, num_classes=10)
y_test = to_categorical(y_test, num_classes=10)

print(x_train.shape)
print(x_train.ndim)
print(x_train.dtype)

print(x_test.shape)
# Out:
# (50000, 32, 32, 3)
# 4
# uint8
# (10000, 32, 32, 3)

# %% [markdown]
# ### Step 3:
#
# Normalize the images

# %%
# Normalize the images
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255
print(x_train.shape)
print(x_test.shape)
# Out:
# (50000, 32, 32, 3)
# (10000, 32, 32, 3)

# %% [markdown]
# ## Defining the model
#
# Here we wil start wit the basic model and we´ll start adding diferent layers, hyperparameters etc to see what works best

# %%
from keras.backend import clear_session
clear_session()

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# Define the model
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(100, activation='relu'))
model.add(Dense(10, activation='softmax'))

# Print the model summary
model.summary()
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 30, 30, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 15, 15, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 7200)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 100)            │       720,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         1,010 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 722,006 (2.75 MB)
#  Trainable params: 722,006 (2.75 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# *   Compile the model using categorical_crossentropy loss, SGD optimizer and use 'accuracy' as the metric.
# *   Use the above defined model to train CIFAR-10 and train the model for 50 epochs with a batch size of 512.

# %%
# Compile the model
model.compile(loss='categorical_crossentropy', optimizer= 'sgd', metrics=['accuracy'])

# Train the model
history = model.fit(x_train, y_train, batch_size=512, epochs=50, validation_data=(x_test, y_test))
# Out:
# Epoch 1/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - accuracy: 0.1634 - loss: 2.2634 - val_accuracy: 0.2386 - val_loss: 2.1443
# Epoch 2/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 53ms/step - accuracy: 0.2535 - loss: 2.1128 - val_accuracy: 0.2912 - val_loss: 2.0252
# Epoch 3/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 53ms/step - accuracy: 0.2950 - loss: 2.0074 - val_accuracy: 0.3172 - val_loss: 1.9556
# Epoch 4/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - accuracy: 0.3133 - loss: 1.9519 - val_accuracy: 0.3317 - val_loss: 1.9170
# Epoch 5/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - accuracy: 0.3297 - loss: 1.9069 - val_accuracy: 0.3367 - val_loss: 1.8894
# Epoch 6/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - accuracy: 0.3435 - loss: 1.8769 - val_accuracy: 0.3390 - val_loss: 1.8647
# Epoch 7/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 54ms/step - accuracy: 0.3571 - loss: 1.8481 - val_accuracy: 0.3640 - val_loss: 1.8251
# Epoch 8/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 53ms/step - accuracy: 0.3640 - loss: 1.8203 - val_accuracy: 0.3533 - val_loss: 1.8309
# Epoch 9/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - accuracy: 0.3776 - loss: 1.7946 - val_accuracy: 0.3333 - val_loss: 1.8299
# Epoch 10/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 53ms/step - accuracy: 0.3837 - loss: 1.7720 - val_accuracy: 0.3831 - val_loss: 1.7574
# Epoch 11/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - accuracy: 0.3897 - loss: 1.7528 - val_accuracy: 0.3783 - val_loss: 1.7482
# Epoch 12/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - accuracy: 0.3987 - loss: 1.7226 - val_accuracy: 0.3991 - val_loss: 1.7102
# Epoch 13/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 56ms/step - accuracy: 0.4130 - loss: 1.6957 - val_accuracy: 0.3971 - val_loss: 1.7078
# Epoch 14/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - accuracy: 0.4153 - loss: 1.6841 - val_accuracy: 0.4142 - val_loss: 1.6747
# Epoch 15/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 6s 60ms/step - accuracy: 0.4243 - loss: 1.6624 - val_accuracy: 0.4292 - val_loss: 1.6409
# Epoch 16/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 6s 57ms/step - accuracy: 0.4311 - loss: 1.6395 - val_accuracy: 0.4212 - val_loss: 1.6358
# Epoch 17/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 6s 57ms/step - accuracy: 0.4339 - loss: 1.6175 - val_accuracy: 0.4406 - val_loss: 1.5984
# Epoch 18/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - accuracy: 0.4367 - loss: 1.6118 - val_accuracy: 0.4469 - val_loss: 1.5833
# Epoch 19/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 6s 57ms/step - accuracy: 0.4495 - loss: 1.5803 - val_accuracy: 0.4201 - val_loss: 1.6235
# Epoch 20/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 6s 57ms/step - accuracy: 0.4525 - loss: 1.5645 - val_accuracy: 0.4391 - val_loss: 1.5665
# Epoch 21/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 6s 60ms/step - accuracy: 0.4581 - loss: 1.5489 - val_accuracy: 0.4629 - val_loss: 1.5272
# Epoch 22/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - accuracy: 0.4719 - loss: 1.5139 - val_accuracy: 0.4435 - val_loss: 1.5690
# Epoch 23/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - accuracy: 0.4755 - loss: 1.5057 - val_accuracy: 0.4601 - val_loss: 1.5139
# Epoch 24/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - accuracy: 0.4803 - loss: 1.4908 - val_accuracy: 0.4809 - val_loss: 1.4792
# Epoch 25/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 6s 57ms/step - accuracy: 0.4827 - loss: 1.4736 - val_accuracy: 0.4720 - val_loss: 1.4891
# Epoch 26/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - accuracy: 0.4869 - loss: 1.4606 - val_accuracy: 0.4882 - val_loss: 1.4490
# Epoch 27/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - accuracy: 0.4975 - loss: 1.4354 - val_accuracy: 0.4787 - val_loss: 1.4724
# Epoch 28/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 6s 57ms/step - accuracy: 0.5001 - loss: 1.4335 - val_accuracy: 0.4995 - val_loss: 1.4229
# Epoch 29/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - accuracy: 0.4970 - loss: 1.4262 - val_accuracy: 0.4711 - val_loss: 1.4800
# Epoch 30/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - accuracy: 0.5088 - loss: 1.3980 - val_accuracy: 0.4972 - val_loss: 1.4088
# Epoch 31/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 6s 57ms/step - accuracy: 0.5077 - loss: 1.3946 - val_accuracy: 0.5047 - val_loss: 1.3854
# Epoch 32/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - accuracy: 0.5157 - loss: 1.3742 - val_accuracy: 0.5104 - val_loss: 1.3842
# Epoch 33/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - accuracy: 0.5210 - loss: 1.3555 - val_accuracy: 0.5202 - val_loss: 1.3629
# Epoch 34/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - accuracy: 0.5253 - loss: 1.3520 - val_accuracy: 0.5138 - val_loss: 1.3705
# Epoch 35/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - accuracy: 0.5281 - loss: 1.3418 - val_accuracy: 0.5247 - val_loss: 1.3452
# Epoch 36/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 6s 60ms/step - accuracy: 0.5325 - loss: 1.3323 - val_accuracy: 0.5182 - val_loss: 1.3758
# Epoch 37/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - accuracy: 0.5319 - loss: 1.3322 - val_accuracy: 0.5344 - val_loss: 1.3288
# Epoch 38/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 6s 61ms/step - accuracy: 0.5391 - loss: 1.3142 - val_accuracy: 0.5383 - val_loss: 1.3189
# Epoch 39/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 6s 64ms/step - accuracy: 0.5445 - loss: 1.3046 - val_accuracy: 0.5389 - val_loss: 1.3108
# Epoch 40/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 6s 65ms/step - accuracy: 0.5465 - loss: 1.2926 - val_accuracy: 0.5286 - val_loss: 1.3189
# Epoch 41/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 6s 66ms/step - accuracy: 0.5508 - loss: 1.2886 - val_accuracy: 0.5282 - val_loss: 1.3375
# Epoch 42/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 7s 67ms/step - accuracy: 0.5492 - loss: 1.2751 - val_accuracy: 0.5451 - val_loss: 1.2871
# Epoch 43/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 7s 67ms/step - accuracy: 0.5601 - loss: 1.2636 - val_accuracy: 0.5424 - val_loss: 1.2951
# Epoch 44/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 7s 67ms/step - accuracy: 0.5570 - loss: 1.2631 - val_accuracy: 0.5401 - val_loss: 1.2919
# Epoch 45/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 7s 68ms/step - accuracy: 0.5593 - loss: 1.2569 - val_accuracy: 0.5415 - val_loss: 1.2918
# Epoch 46/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - accuracy: 0.5636 - loss: 1.2511 - val_accuracy: 0.5532 - val_loss: 1.2781
# Epoch 47/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 7s 70ms/step - accuracy: 0.5659 - loss: 1.2431 - val_accuracy: 0.5491 - val_loss: 1.2804
# Epoch 48/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 7s 67ms/step - accuracy: 0.5627 - loss: 1.2550 - val_accuracy: 0.5519 - val_loss: 1.2684
# Epoch 49/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - accuracy: 0.5727 - loss: 1.2261 - val_accuracy: 0.5613 - val_loss: 1.2528
# Epoch 50/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 7s 75ms/step - accuracy: 0.5683 - loss: 1.2360 - val_accuracy: 0.5609 - val_loss: 1.2536

# %% [markdown]
# *   Plot the cross entropy loss curve and the accuracy curve

# %%
# Plot Cross Entropy Loss curve
plt.subplot(211)
plt.title('Cross Entropy Loss')
plt.plot(history.history['loss'], color='red', label='train')


# Plot accuracy curve
plt.subplot(212)
plt.title('Classification Accuracy')
plt.plot(history.history['accuracy'], color='green', label='train')
plt.show()

# %%
# Evaluate the model on the test data
test_loss, test_acc = model.evaluate(x_test, y_test)

print(f'Test accuracy: {test_acc:.2f}')
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5592 - loss: 1.2509
# Test accuracy: 0.56

# %%
# Predict the output for the test split
y_pred = model.predict(x_test)

# Convert the predictions to class labels
y_pred_class = np.argmax(y_pred, axis=1)

# Plot the confusion matrix
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt

cm = confusion_matrix(np.argmax(y_test, axis=1), y_pred_class)

plt.figure(figsize=(10, 8))
plt.imshow(cm, interpolation='nearest', cmap='Reds')
plt.title('Confusion Matrix')
plt.colorbar()

# Add numbers to the confusion matrix
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        plt.text(j, i, cm[i, j], ha='center', va='center', color='black')

plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
